# %%
import src.dataset as dataset

# df = dataset.import_k_para('./res/K_para.csv')
# print(df)
df = dataset.build_dataset(cache='./res/dataset.pkl')
 df.to_csv('./res/dataset.csv')
df
# Out:
#        i                                                 Kp  C  \
# 0      0  [-4.4813, 30.3625, -5.4895, 0.6087, -0.0285, -...  1
# 1      0  [-4.4813, 30.3625, -5.4895, 0.6087, -0.0285, -...  1
# 2      0  [-4.4813, 30.3625, -5.4895, 0.6087, -0.0285, -...  1
# 3      0  [-4.4813, 30.3625, -5.4895, 0.6087, -0.0285, -...  1
# 4      0  [-4.4813, 30.3625, -5.4895, 0.6087, -0.0285, -...  1
# ...   ..                                                ... ..
# 6523  33  [-4.1835, 83.7601, -14.0218, 1.4864, -0.0676, ...  1
# 6524  33  [-4.1835, 83.7601, -14.0218, 1.4864, -0.0676, ...  1
# 6525  33  [-4.1835, 83.7601, -14.0218, 1.4864, -0.0676, ...  1
# 6526  33  [-4.1835, 83.7601, -14.0218, 1.4864, -0.0676, ...  1
# 6527  33  [-4.1835, 83.7601, -14.0218, 1.4864, -0.0676, ...  1
#
#                                                     soc  \
# 0     [1.0, 0.9967105263157895, 0.993421052631579, 0...
# 1     [1.0, 0.9983974358974359, 0.9967948717948718, ...
# ...

# %%
# plot the first entry in the dataframe
import matplotlib.pyplot as plt

for i, row in enumerate(df.itertuples()):
    assert row.SoC.shape == row.I.shape == row.V.shape == row.t.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       2 import matplotlib.pyplot as plt
#       4 for i, row in enumerate(df.itertuples()):
# ----> 5     assert row.SoC.shape == row.I.shape == row.V.shape == row.t.shape
#
# AttributeError: 'Pandas' object has no attribute 'SoC'
